# %%
a=int(input("enter any no"))
# Out:
# enter any no5
# 5

# %%
if a%2==0:
    print(" ")
else:
    print(a)
a+=1
if a%2==0:
    print(" ")
else:
    print(a)
a+=1
if a%2==0:
    print(" ")
else:
    print(a)
a+=1
if a%2==0:
    print(" ")
else:
    print(a)
a+=1
if a%2==0:
    print(" ")
else:
    print(a)
a+=1
# Out:
# 5
#
# 7
#
# 9

# %%
x=5
y=10
while x<=y:
   if x%2==0:
      print(" ")
   else:
      print(x)
   x+=1
# Out:
# 5
#
# 7
#
# 9

# %%
#print succesive no with values addition in three between a and b
a=int(input("enter any no"))
b=int(input("enter any no"))
while a<b:

    print(a)
    a+=3
print("final value of a",a)
# Out:
# enter any no5
# enter any no15
# 5
# 8
# 11
# 14
# final value of a 17

# %%
5
# Out:
# 5

# %%
1,12,123,1234,12345
i=1
j=1
while i<=5:
  print(j)
  i=i+1
  j=(j*10)+i
# Out:
# 1
# 12
# 123
# 1234
# 12345

# %%
#1,4,9,16.....(10 steps)
i=1
j=1
k=3
while 1<=10:
   print(j)
   j=j+k
   k=k+2
   i=i+1
# Out:
# Streaming output truncated to the last 5000 lines.
# 7074996769
# 7075164996
# 7075333225
# 7075501456
# 7075669689
# 7075837924
# 7076006161
# 7076174400
# 7076342641
# 7076510884
# 7076679129
# 7076847376
# 7077015625
# 7077183876
# 7077352129
# 7077520384
# 7077688641
# 7077856900
# 7078025161
# 7078193424
# 7078361689
# 7078529956
# 7078698225
# 7078866496
# 7079034769
# 7079203044
# 7079371321
# 7079539600
# 7079707881
# 7079876164
# 7080044449
# 7080212736
# 7080381025
# 7080549316
# 7080717609
# 7080885904
# 7081054201
# 7081222500
# 7081390801
# 7081559104
# 7081727409
# 7081895716
# 7082064025
# 7082232336
# 7082400649
# 7082568964
# 7082737281
# 7082905600
# 7083073921
# 7083242244
# 7083410569
# 7083578896
# 7083747225
# 7083915556
# 7084083889
# 7084252224
# 7084420561
# 7084588900
# 7084757241
# 7084925584
# 7085093929
# 7085262276
# 7085430625
# 7085598976
# 7085767329
# 7085935684
# 7086104041
# 7086272400
# 7086440761
# 7086609124
# 7086777489
# 7086945856
# ...
